# %%
(require booleans redex/reduction-semantics)

# %% [markdown]
# Some possibly helpful laws:
#
# - Posulate 1: ¬( GO ∨ (RES ∧ SEL)) implies all E' is 0 and all kn are 0.
# - - Correlary 1: This holds for ¬(GO ∨ SEL)
# - - Correlary 2: This holds for ¬(GO ∨ RES)
# - Postulate 2: forall n m, m != n, ¬ (kn ^ km), that is at most one k wire is selected.
# - Postulate 3: SEL can only be 1 if, at some instant in the past GO was 1. (?)

# %%
(define/ppl start #:no-check
  ((Knr = GO)
   (Kn = (or Knr Knl))
   (K0 = K0r)
   (Kx = Kxr)
   (Sel = Selr)))
# Out:
# (Knr = GO)
# (Kn = (or Knr Knl))
# (K0 = K0r)
# (Kx = Kxr)
# (Sel = Selr)

# %%
(define/ppl end #:no-check
  ((Kn = GO)
   (K0 = false)
   (Kx = false)
   (Sel = false)))
# Out:
# (Kn = GO)
# (K0 = false)
# (Kx = false)
# (Sel = false)

# %%
(assert-same (term start) (term end))
# Out:
# equal-class: the diff:
#  '((("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = true) (K0r = true) (Kxr = true) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = true) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = true) (K0r = true) (Kxr = true) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = true) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = true) (K0r = true) (Kxr = true) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = true) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = true) (K0r = true) (Kxr = false) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = false) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = true) (K0r = true) (Kxr = false) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = false) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = true) (K0r = true) (Kxr = false) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = false) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = true) (K0r = true) (Kxr = ⊥) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = ⊥) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = true) (K0r = true) (Kxr = ⊥) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = ⊥) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = true) (K0r = true) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = true) (Knl = true) (K0r = false) (Kxr = true) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = true) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = true) (Knl = true) (K0r = false) (Kxr = true) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = true) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = true) (Knl = true) (K0r = false) (Kxr = true) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = true) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Sel = false))
#    ((GO = true) (Knl = true) (K0r = false) (Kxr = false) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = false) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Sel = false))
#    ((GO = true) (Knl = true) (K0r = false) (Kxr = false) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = false) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = true) (Knl = true) (K0r = false) (Kxr = ⊥) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = ⊥) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = true) (Knl = true) (K0r = false) (Kxr = ⊥) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = ⊥) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = true) (Knl = true) (K0r = false) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = true) (K0r = ⊥) (Kxr = true) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = true) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = true) (K0r = ⊥) (Kxr = true) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = true) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = true) (K0r = ⊥) (Kxr = true) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = true) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = true) (K0r = ⊥) (Kxr = false) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = false) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = true) (K0r = ⊥) (Kxr = false) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = false) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = true) (K0r = ⊥) (Kxr = false) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = false) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = true) (K0r = ⊥) (Kxr = ⊥) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = ⊥) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = true) (K0r = ⊥) (Kxr = ⊥) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = ⊥) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = true) (K0r = ⊥) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = false) (K0r = true) (Kxr = true) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = true) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = false) (K0r = true) (Kxr = true) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = true) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = false) (K0r = true) (Kxr = true) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = true) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = false) (K0r = true) (Kxr = false) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = false) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = false) (K0r = true) (Kxr = false) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = false) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = false) (K0r = true) (Kxr = false) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = false) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = false) (K0r = true) (Kxr = ⊥) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = ⊥) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = false) (K0r = true) (Kxr = ⊥) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = ⊥) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = false) (K0r = true) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = true) (Knl = false) (K0r = false) (Kxr = true) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = true) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = true) (Knl = false) (K0r = false) (Kxr = true) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = true) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = true) (Knl = false) (K0r = false) (Kxr = true) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = true) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Sel = false))
#    ((GO = true) (Knl = false) (K0r = false) (Kxr = false) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = false) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Sel = false))
#    ((GO = true) (Knl = false) (K0r = false) (Kxr = false) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = false) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = true) (Knl = false) (K0r = false) (Kxr = ⊥) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = ⊥) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = true) (Knl = false) (K0r = false) (Kxr = ⊥) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = ⊥) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = true) (Knl = false) (K0r = false) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = false) (K0r = ⊥) (Kxr = true) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = true) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = false) (K0r = ⊥) (Kxr = true) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = true) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = false) (K0r = ⊥) (Kxr = true) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = true) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = false) (K0r = ⊥) (Kxr = false) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = false) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = false) (K0r = ⊥) (Kxr = false) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = false) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = false) (K0r = ⊥) (Kxr = false) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = false) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = false) (K0r = ⊥) (Kxr = ⊥) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = ⊥) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = false) (K0r = ⊥) (Kxr = ⊥) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = ⊥) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = false) (K0r = ⊥) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = ⊥) (K0r = true) (Kxr = true) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = true) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = ⊥) (K0r = true) (Kxr = true) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = true) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = ⊥) (K0r = true) (Kxr = true) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = true) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = ⊥) (K0r = true) (Kxr = false) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = false) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = ⊥) (K0r = true) (Kxr = false) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = false) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = ⊥) (K0r = true) (Kxr = false) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = false) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = ⊥) (K0r = true) (Kxr = ⊥) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = ⊥) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = ⊥) (K0r = true) (Kxr = ⊥) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = ⊥) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = ⊥) (K0r = true) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = true) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = true) (Knl = ⊥) (K0r = false) (Kxr = true) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = true) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = true) (Knl = ⊥) (K0r = false) (Kxr = true) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = true) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = true) (Knl = ⊥) (K0r = false) (Kxr = true) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = true) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Sel = false))
#    ((GO = true) (Knl = ⊥) (K0r = false) (Kxr = false) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = false) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Sel = false))
#    ((GO = true) (Knl = ⊥) (K0r = false) (Kxr = false) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = false) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = true) (Knl = ⊥) (K0r = false) (Kxr = ⊥) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = ⊥) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = true) (Knl = ⊥) (K0r = false) (Kxr = ⊥) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = ⊥) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = true) (Knl = ⊥) (K0r = false) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = false) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = ⊥) (K0r = ⊥) (Kxr = true) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = true) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = ⊥) (K0r = ⊥) (Kxr = true) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = true) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = ⊥) (K0r = ⊥) (Kxr = true) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = true) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = ⊥) (K0r = ⊥) (Kxr = false) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = false) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = ⊥) (K0r = ⊥) (Kxr = false) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = false) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = ⊥) (K0r = ⊥) (Kxr = false) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = false) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = ⊥) (K0r = ⊥) (Kxr = ⊥) (Selr = true))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = ⊥) (Sel = true))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = ⊥) (K0r = ⊥) (Kxr = ⊥) (Selr = false))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = ⊥) (Sel = false))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = true) (Knl = ⊥) (K0r = ⊥) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = true) (Kn = true) (K0 = ⊥) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = true) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = true) (Kxr = true) (Selr = true))
#    ((Knr = false) (Kn = true) (K0 = true) (Kx = true) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = true) (Kxr = true) (Selr = false))
#    ((Knr = false) (Kn = true) (K0 = true) (Kx = true) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = true) (Kxr = true) (Selr = ⊥))
#    ((Knr = false) (Kn = true) (K0 = true) (Kx = true) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = true) (Kxr = false) (Selr = true))
#    ((Knr = false) (Kn = true) (K0 = true) (Kx = false) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = true) (Kxr = false) (Selr = false))
#    ((Knr = false) (Kn = true) (K0 = true) (Kx = false) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = true) (Kxr = false) (Selr = ⊥))
#    ((Knr = false) (Kn = true) (K0 = true) (Kx = false) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = true) (Kxr = ⊥) (Selr = true))
#    ((Knr = false) (Kn = true) (K0 = true) (Kx = ⊥) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = true) (Kxr = ⊥) (Selr = false))
#    ((Knr = false) (Kn = true) (K0 = true) (Kx = ⊥) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = true) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = false) (Kn = true) (K0 = true) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = false) (Kxr = true) (Selr = true))
#    ((Knr = false) (Kn = true) (K0 = false) (Kx = true) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = false) (Kxr = true) (Selr = false))
#    ((Knr = false) (Kn = true) (K0 = false) (Kx = true) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = false) (Kxr = true) (Selr = ⊥))
#    ((Knr = false) (Kn = true) (K0 = false) (Kx = true) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = false) (Kxr = false) (Selr = true))
#    ((Knr = false) (Kn = true) (K0 = false) (Kx = false) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = false) (Kxr = false) (Selr = false))
#    ((Knr = false) (Kn = true) (K0 = false) (Kx = false) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = false) (Kxr = false) (Selr = ⊥))
#    ((Knr = false) (Kn = true) (K0 = false) (Kx = false) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = false) (Kxr = ⊥) (Selr = true))
#    ((Knr = false) (Kn = true) (K0 = false) (Kx = ⊥) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = false) (Kxr = ⊥) (Selr = false))
#    ((Knr = false) (Kn = true) (K0 = false) (Kx = ⊥) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = false) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = false) (Kn = true) (K0 = false) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = ⊥) (Kxr = true) (Selr = true))
#    ((Knr = false) (Kn = true) (K0 = ⊥) (Kx = true) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = ⊥) (Kxr = true) (Selr = false))
#    ((Knr = false) (Kn = true) (K0 = ⊥) (Kx = true) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = ⊥) (Kxr = true) (Selr = ⊥))
#    ((Knr = false) (Kn = true) (K0 = ⊥) (Kx = true) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = ⊥) (Kxr = false) (Selr = true))
#    ((Knr = false) (Kn = true) (K0 = ⊥) (Kx = false) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = ⊥) (Kxr = false) (Selr = false))
#    ((Knr = false) (Kn = true) (K0 = ⊥) (Kx = false) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = ⊥) (Kxr = false) (Selr = ⊥))
#    ((Knr = false) (Kn = true) (K0 = ⊥) (Kx = false) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = ⊥) (Kxr = ⊥) (Selr = true))
#    ((Knr = false) (Kn = true) (K0 = ⊥) (Kx = ⊥) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = ⊥) (Kxr = ⊥) (Selr = false))
#    ((Knr = false) (Kn = true) (K0 = ⊥) (Kx = ⊥) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = true) (K0r = ⊥) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = false) (Kn = true) (K0 = ⊥) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = false) (Knl = false) (K0r = true) (Kxr = true) (Selr = true))
#    ((Knr = false) (Kn = false) (K0 = true) (Kx = true) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = false) (Knl = false) (K0r = true) (Kxr = true) (Selr = false))
#    ((Knr = false) (Kn = false) (K0 = true) (Kx = true) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = false) (Knl = false) (K0r = true) (Kxr = true) (Selr = ⊥))
#    ((Knr = false) (Kn = false) (K0 = true) (Kx = true) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = false) (Knl = false) (K0r = true) (Kxr = false) (Selr = true))
#    ((Knr = false) (Kn = false) (K0 = true) (Kx = false) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = false) (Knl = false) (K0r = true) (Kxr = false) (Selr = false))
#    ((Knr = false) (Kn = false) (K0 = true) (Kx = false) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = false) (Knl = false) (K0r = true) (Kxr = false) (Selr = ⊥))
#    ((Knr = false) (Kn = false) (K0 = true) (Kx = false) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = false) (Knl = false) (K0r = true) (Kxr = ⊥) (Selr = true))
#    ((Knr = false) (Kn = false) (K0 = true) (Kx = ⊥) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = false) (Knl = false) (K0r = true) (Kxr = ⊥) (Selr = false))
#    ((Knr = false) (Kn = false) (K0 = true) (Kx = ⊥) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = false) (Knl = false) (K0r = true) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = false) (Kn = false) (K0 = true) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = false) (Knl = false) (K0r = false) (Kxr = true) (Selr = true))
#    ((Knr = false) (Kn = false) (K0 = false) (Kx = true) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = false) (Knl = false) (K0r = false) (Kxr = true) (Selr = false))
#    ((Knr = false) (Kn = false) (K0 = false) (Kx = true) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = false) (Knl = false) (K0r = false) (Kxr = true) (Selr = ⊥))
#    ((Knr = false) (Kn = false) (K0 = false) (Kx = true) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Sel = false))
#    ((GO = false) (Knl = false) (K0r = false) (Kxr = false) (Selr = true))
#    ((Knr = false) (Kn = false) (K0 = false) (Kx = false) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Sel = false))
#    ((GO = false) (Knl = false) (K0r = false) (Kxr = false) (Selr = ⊥))
#    ((Knr = false) (Kn = false) (K0 = false) (Kx = false) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = false) (Knl = false) (K0r = false) (Kxr = ⊥) (Selr = true))
#    ((Knr = false) (Kn = false) (K0 = false) (Kx = ⊥) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = false) (Knl = false) (K0r = false) (Kxr = ⊥) (Selr = false))
#    ((Knr = false) (Kn = false) (K0 = false) (Kx = ⊥) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = false) (Knl = false) (K0r = false) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = false) (Kn = false) (K0 = false) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = false) (Knl = false) (K0r = ⊥) (Kxr = true) (Selr = true))
#    ((Knr = false) (Kn = false) (K0 = ⊥) (Kx = true) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = false) (Knl = false) (K0r = ⊥) (Kxr = true) (Selr = false))
#    ((Knr = false) (Kn = false) (K0 = ⊥) (Kx = true) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = false) (Knl = false) (K0r = ⊥) (Kxr = true) (Selr = ⊥))
#    ((Knr = false) (Kn = false) (K0 = ⊥) (Kx = true) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = false) (Knl = false) (K0r = ⊥) (Kxr = false) (Selr = true))
#    ((Knr = false) (Kn = false) (K0 = ⊥) (Kx = false) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = false) (Knl = false) (K0r = ⊥) (Kxr = false) (Selr = false))
#    ((Knr = false) (Kn = false) (K0 = ⊥) (Kx = false) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = false) (Knl = false) (K0r = ⊥) (Kxr = false) (Selr = ⊥))
#    ((Knr = false) (Kn = false) (K0 = ⊥) (Kx = false) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = false) (Knl = false) (K0r = ⊥) (Kxr = ⊥) (Selr = true))
#    ((Knr = false) (Kn = false) (K0 = ⊥) (Kx = ⊥) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = false) (Knl = false) (K0r = ⊥) (Kxr = ⊥) (Selr = false))
#    ((Knr = false) (Kn = false) (K0 = ⊥) (Kx = ⊥) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = false) (Knl = false) (K0r = ⊥) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = false) (Kn = false) (K0 = ⊥) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = true) (Kxr = true) (Selr = true))
#    ((Knr = false) (Kn = ⊥) (K0 = true) (Kx = true) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = true) (Kxr = true) (Selr = false))
#    ((Knr = false) (Kn = ⊥) (K0 = true) (Kx = true) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = true) (Kxr = true) (Selr = ⊥))
#    ((Knr = false) (Kn = ⊥) (K0 = true) (Kx = true) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = true) (Kxr = false) (Selr = true))
#    ((Knr = false) (Kn = ⊥) (K0 = true) (Kx = false) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = true) (Kxr = false) (Selr = false))
#    ((Knr = false) (Kn = ⊥) (K0 = true) (Kx = false) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = true) (Kxr = false) (Selr = ⊥))
#    ((Knr = false) (Kn = ⊥) (K0 = true) (Kx = false) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = true) (Kxr = ⊥) (Selr = true))
#    ((Knr = false) (Kn = ⊥) (K0 = true) (Kx = ⊥) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = true) (Kxr = ⊥) (Selr = false))
#    ((Knr = false) (Kn = ⊥) (K0 = true) (Kx = ⊥) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = true) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = false) (Kn = ⊥) (K0 = true) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = false) (Kxr = true) (Selr = true))
#    ((Knr = false) (Kn = ⊥) (K0 = false) (Kx = true) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = false) (Kxr = true) (Selr = false))
#    ((Knr = false) (Kn = ⊥) (K0 = false) (Kx = true) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = false) (Kxr = true) (Selr = ⊥))
#    ((Knr = false) (Kn = ⊥) (K0 = false) (Kx = true) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = false) (Kxr = false) (Selr = true))
#    ((Knr = false) (Kn = ⊥) (K0 = false) (Kx = false) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = false) (Kxr = false) (Selr = false))
#    ((Knr = false) (Kn = ⊥) (K0 = false) (Kx = false) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = false) (Kxr = false) (Selr = ⊥))
#    ((Knr = false) (Kn = ⊥) (K0 = false) (Kx = false) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = false) (Kxr = ⊥) (Selr = true))
#    ((Knr = false) (Kn = ⊥) (K0 = false) (Kx = ⊥) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = false) (Kxr = ⊥) (Selr = false))
#    ((Knr = false) (Kn = ⊥) (K0 = false) (Kx = ⊥) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = false) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = false) (Kn = ⊥) (K0 = false) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = ⊥) (Kxr = true) (Selr = true))
#    ((Knr = false) (Kn = ⊥) (K0 = ⊥) (Kx = true) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = ⊥) (Kxr = true) (Selr = false))
#    ((Knr = false) (Kn = ⊥) (K0 = ⊥) (Kx = true) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = ⊥) (Kxr = true) (Selr = ⊥))
#    ((Knr = false) (Kn = ⊥) (K0 = ⊥) (Kx = true) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = ⊥) (Kxr = false) (Selr = true))
#    ((Knr = false) (Kn = ⊥) (K0 = ⊥) (Kx = false) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = ⊥) (Kxr = false) (Selr = false))
#    ((Knr = false) (Kn = ⊥) (K0 = ⊥) (Kx = false) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = ⊥) (Kxr = false) (Selr = ⊥))
#    ((Knr = false) (Kn = ⊥) (K0 = ⊥) (Kx = false) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = ⊥) (Kxr = ⊥) (Selr = true))
#    ((Knr = false) (Kn = ⊥) (K0 = ⊥) (Kx = ⊥) (Sel = true))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = ⊥) (Kxr = ⊥) (Selr = false))
#    ((Knr = false) (Kn = ⊥) (K0 = ⊥) (Kx = ⊥) (Sel = false))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = false))
#    ((GO = false) (Knl = ⊥) (K0r = ⊥) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = false) (Kn = ⊥) (K0 = ⊥) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = false) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = true) (Kxr = true) (Selr = true))
#    ((Knr = ⊥) (Kn = true) (K0 = true) (Kx = true) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = true) (Kxr = true) (Selr = false))
#    ((Knr = ⊥) (Kn = true) (K0 = true) (Kx = true) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = true) (Kxr = true) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = true) (K0 = true) (Kx = true) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = true) (Kxr = false) (Selr = true))
#    ((Knr = ⊥) (Kn = true) (K0 = true) (Kx = false) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = true) (Kxr = false) (Selr = false))
#    ((Knr = ⊥) (Kn = true) (K0 = true) (Kx = false) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = true) (Kxr = false) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = true) (K0 = true) (Kx = false) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = true) (Kxr = ⊥) (Selr = true))
#    ((Knr = ⊥) (Kn = true) (K0 = true) (Kx = ⊥) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = true) (Kxr = ⊥) (Selr = false))
#    ((Knr = ⊥) (Kn = true) (K0 = true) (Kx = ⊥) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = true) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = true) (K0 = true) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = false) (Kxr = true) (Selr = true))
#    ((Knr = ⊥) (Kn = true) (K0 = false) (Kx = true) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = false) (Kxr = true) (Selr = false))
#    ((Knr = ⊥) (Kn = true) (K0 = false) (Kx = true) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = false) (Kxr = true) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = true) (K0 = false) (Kx = true) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = false) (Kxr = false) (Selr = true))
#    ((Knr = ⊥) (Kn = true) (K0 = false) (Kx = false) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = false) (Kxr = false) (Selr = false))
#    ((Knr = ⊥) (Kn = true) (K0 = false) (Kx = false) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = false) (Kxr = false) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = true) (K0 = false) (Kx = false) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = false) (Kxr = ⊥) (Selr = true))
#    ((Knr = ⊥) (Kn = true) (K0 = false) (Kx = ⊥) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = false) (Kxr = ⊥) (Selr = false))
#    ((Knr = ⊥) (Kn = true) (K0 = false) (Kx = ⊥) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = false) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = true) (K0 = false) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = ⊥) (Kxr = true) (Selr = true))
#    ((Knr = ⊥) (Kn = true) (K0 = ⊥) (Kx = true) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = ⊥) (Kxr = true) (Selr = false))
#    ((Knr = ⊥) (Kn = true) (K0 = ⊥) (Kx = true) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = ⊥) (Kxr = true) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = true) (K0 = ⊥) (Kx = true) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = ⊥) (Kxr = false) (Selr = true))
#    ((Knr = ⊥) (Kn = true) (K0 = ⊥) (Kx = false) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = ⊥) (Kxr = false) (Selr = false))
#    ((Knr = ⊥) (Kn = true) (K0 = ⊥) (Kx = false) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = ⊥) (Kxr = false) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = true) (K0 = ⊥) (Kx = false) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = ⊥) (Kxr = ⊥) (Selr = true))
#    ((Knr = ⊥) (Kn = true) (K0 = ⊥) (Kx = ⊥) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = ⊥) (Kxr = ⊥) (Selr = false))
#    ((Knr = ⊥) (Kn = true) (K0 = ⊥) (Kx = ⊥) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kn = ⊥))
#    ((GO = ⊥) (Knl = true) (K0r = ⊥) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = true) (K0 = ⊥) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = false) (K0r = true) (Kxr = true) (Selr = true))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = true) (Kx = true) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = false) (K0r = true) (Kxr = true) (Selr = false))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = true) (Kx = true) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = false) (K0r = true) (Kxr = true) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = true) (Kx = true) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = false) (K0r = true) (Kxr = false) (Selr = true))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = true) (Kx = false) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = false) (K0r = true) (Kxr = false) (Selr = false))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = true) (Kx = false) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = false) (K0r = true) (Kxr = false) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = true) (Kx = false) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = false) (K0r = true) (Kxr = ⊥) (Selr = true))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = true) (Kx = ⊥) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = false) (K0r = true) (Kxr = ⊥) (Selr = false))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = true) (Kx = ⊥) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = false) (K0r = true) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = true) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = ⊥) (Knl = false) (K0r = false) (Kxr = true) (Selr = true))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = false) (Kx = true) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = ⊥) (Knl = false) (K0r = false) (Kxr = true) (Selr = false))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = false) (Kx = true) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = ⊥) (Knl = false) (K0r = false) (Kxr = true) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = false) (Kx = true) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Sel = false))
#    ((GO = ⊥) (Knl = false) (K0r = false) (Kxr = false) (Selr = true))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = false) (Kx = false) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Sel = false))
#    ((GO = ⊥) (Knl = false) (K0r = false) (Kxr = false) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = false) (Kx = false) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = ⊥) (Knl = false) (K0r = false) (Kxr = ⊥) (Selr = true))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = false) (Kx = ⊥) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = ⊥) (Knl = false) (K0r = false) (Kxr = ⊥) (Selr = false))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = false) (Kx = ⊥) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = ⊥) (Knl = false) (K0r = false) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = false) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = false) (K0r = ⊥) (Kxr = true) (Selr = true))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = ⊥) (Kx = true) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = false) (K0r = ⊥) (Kxr = true) (Selr = false))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = ⊥) (Kx = true) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = false) (K0r = ⊥) (Kxr = true) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = ⊥) (Kx = true) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = false) (K0r = ⊥) (Kxr = false) (Selr = true))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = ⊥) (Kx = false) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = false) (K0r = ⊥) (Kxr = false) (Selr = false))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = ⊥) (Kx = false) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = false) (K0r = ⊥) (Kxr = false) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = ⊥) (Kx = false) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = false) (K0r = ⊥) (Kxr = ⊥) (Selr = true))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = ⊥) (Kx = ⊥) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = false) (K0r = ⊥) (Kxr = ⊥) (Selr = false))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = ⊥) (Kx = ⊥) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = false) (K0r = ⊥) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = ⊥) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = true) (Kxr = true) (Selr = true))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = true) (Kx = true) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = true) (Kxr = true) (Selr = false))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = true) (Kx = true) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = true) (Kxr = true) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = true) (Kx = true) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = true) (Kxr = false) (Selr = true))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = true) (Kx = false) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = true) (Kxr = false) (Selr = false))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = true) (Kx = false) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = true) (Kxr = false) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = true) (Kx = false) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = true) (Kxr = ⊥) (Selr = true))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = true) (Kx = ⊥) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = true) (Kxr = ⊥) (Selr = false))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = true) (Kx = ⊥) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = true) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = true) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = false) (Kxr = true) (Selr = true))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = false) (Kx = true) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = false) (Kxr = true) (Selr = false))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = false) (Kx = true) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = false) (Kxr = true) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = false) (Kx = true) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Sel = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = false) (Kxr = false) (Selr = true))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = false) (Kx = false) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Sel = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = false) (Kxr = false) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = false) (Kx = false) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = false) (Kxr = ⊥) (Selr = true))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = false) (Kx = ⊥) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = false) (Kxr = ⊥) (Selr = false))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = false) (Kx = ⊥) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (Kx = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = false) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = false) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = ⊥) (Kxr = true) (Selr = true))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = ⊥) (Kx = true) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = ⊥) (Kxr = true) (Selr = false))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = ⊥) (Kx = true) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = ⊥) (Kxr = true) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = ⊥) (Kx = true) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = ⊥) (Kxr = false) (Selr = true))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = ⊥) (Kx = false) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = ⊥) (Kxr = false) (Selr = false))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = ⊥) (Kx = false) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = ⊥) (Kxr = false) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = ⊥) (Kx = false) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = ⊥) (Kxr = ⊥) (Selr = true))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = ⊥) (Kx = ⊥) (Sel = true))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = ⊥) (Kxr = ⊥) (Selr = false))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = ⊥) (Kx = ⊥) (Sel = false))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false)))
#   (("a broken clause:" (K0 = false))
#    ((GO = ⊥) (Knl = ⊥) (K0r = ⊥) (Kxr = ⊥) (Selr = ⊥))
#    ((Knr = ⊥) (Kn = ⊥) (K0 = ⊥) (Kx = ⊥) (Sel = ⊥))
#    ((Kn = ⊥) (K0 = false) (Kx = false) (Sel = false))))
#   context...:
#    eval-one-top12
#    /Applications/Racket/racket/share/pkgs/sandbox-lib/racket/sandbox.rkt:510:0: call-with-custodian-shutdown
#    /Applications/Racket/racket/collects/racket/private/more-scheme.rkt:148:2: call-with-break-parameterization
#    .../more-scheme.rkt:261:28
#    /Applications/Racket/racket/share/pkgs/sandbox-lib/racket/sandbox.rkt:878:5: loop
